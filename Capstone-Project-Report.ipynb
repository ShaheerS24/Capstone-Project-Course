# %% [markdown]
# # Capstone Report IBM #
# By Shaheer Shahab

# %% [markdown]
# #### Introduction
# A chef I know wants to open up a high-end steakhouse in Toronto and has hired me as a consultant to help him decide which neighborhood would be the best place to open it

# %% [markdown]
# #### Problem Description
# Where should the chef open up his high-end steakhouse in the city of Toronto that will guarantee a lot of customer?

# %% [markdown]
# #### Requirements
# 1.	The steakhouse needs to be accessible to people who can afford it (have a lot of money)
# 2.	The steakhouse needs to be in a well-populated area

# %% [markdown]
# #### Data Description
# 1.	Toronto neighborhoods by their postal code
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# 2.	Latitude/Longitude coordinates
# https://cocl.us/Geospatial_data
# 3.	Toronto neighborhood populations by postal code
# https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/hlt-fst/pd-pl/Tables/File.cfm?T=1201&SR=1&RPP=9999&PR=0&CMA=0&CSD=0&S=22&O=A&Lang=Eng&OFT=CSV
# 4.	 After tax income for Toronto neighbourhoods
# https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods
# 5. Restuarants and venues
# https://api.foursquare.com

# %% [markdown]
# #### Reason for needing each data link
# 1.	This will give us the postal codes for each neighborhood
# 2.	This will match each postal code with longitude/latitudes for the map
# 3.	This will give us the data for each neighborhoods population
# 4.	This will provide us the income for each neighborhood

# %% [markdown]
# ### Methodology
#
# 1. I loaded and then imported Toronto Postal Code Data
# 2. Merged Postal Codes with their corresponding populations
# 3. Merged Postal Codes with Incomes
# 2. Merged geospatial coordinates with Toronto postal codes
# 3. Merged most common venues visited with Population, income data to create new data frame
# 4. Used folium to plot new data frame on a map with coordinates for the best location

# %% [markdown]
# ### Results
#
# I was able to find a location that would be best suited for a Steakhouse in the neighbourhood of Moore Park
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Discussion
#
# Looking at the average incomes of each neigbhorhood showed me that the wealth of Toronto is concentrated in the central / downtown area which makes sense as this is the case for many othe cities in the world as those areas have the highest land values and therefore only the people in high income brackets are able to afford living there.
#
# I was originally going to go focus solely using clusters but it didnt make much sense for me to do so as I just needed to find the best location in the entire city as per my self-given prompt

# %% [markdown]
# ### Conclusion
#
# Using the tools I have used, I can say with definite certainty that my results were accurate and based on these variables and data, this location that was found is the best area for a high-end steakhouse.
